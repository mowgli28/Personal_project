# %% [markdown]
# <a href="https://colab.research.google.com/github/mowgli28/Personal_project/blob/master/Personal_Project_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# https://data.world/datafiniti/palm-springs-vacation-rentals
df = pd.read_csv('https://github.com/mowgli28/Personal_project/blob/master/rental_data.numbers?raw=true')

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/3ao62cd373dryssfetxe4hk4uo537n')

# %%
df
# Out:
#                                          city country             dateAdded  \
# 0                                Palm Springs      US  2015-09-24T17:09:30Z
# 1                                Palm Springs      US  2015-09-24T17:09:30Z
# 2                                Palm Springs      US  2015-09-24T17:09:30Z
# 3                                Palm Springs      US  2015-09-24T17:09:30Z
# 4                                Palm Springs      US  2015-09-24T17:09:30Z
# 5                                Palm Springs      US  2015-09-24T17:09:30Z
# 6                                Palm Springs      US  2015-09-24T17:09:30Z
# 7                                Palm Springs      US  2015-09-24T17:09:30Z
# 8                                Palm Springs      US  2015-09-24T17:09:30Z
# 9                                Palm Springs      US  2015-09-24T17:09:30Z
# 10                               Palm Springs      US  2015-09-24T17:09:30Z
# ...
